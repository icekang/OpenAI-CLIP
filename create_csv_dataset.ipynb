# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
pre_final_coregistration = Path('/home/gridsan/nchutisilp/datasets/Mariia/Pre_Final')

image_filenames1 = pre_final_coregistration.glob('*Pre_target_Final.nii.gz')
image_filenames2 = pre_final_coregistration.glob('*Final_reg.nii.gz')

image_filenames1 = list(image_filenames1)
image_filenames2 = list(image_filenames2)

image_filenames1.sort()
image_filenames2.sort()

for image_path1, image_path2 in zip(image_filenames1, image_filenames2):
    last_numeric_index = 6
    if not image_path1.name[:last_numeric_index].isnumeric():
        last_numeric_index = 5
    assert image_path1.name[:last_numeric_index] == image_path2.name[:last_numeric_index], f'Image paths do not align, {image_path1} and {image_path2} should have the same case id'

# %%
data = pd.DataFrame({
    'image1': image_filenames1,
    'image2': image_filenames2
})
data['id'] = data.index
data
# Out:
#                                                 image1  \
# 0    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 1    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 2    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 3    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 4    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# ..                                                 ...
# 117  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 118  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 119  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 120  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 121  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
#
#                                                 image2   id
# 0    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...    0
# 1    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...    1
# 2    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...    2
# 3    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...    3
# 4    /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...    4
# ..                                                 ...  ...
# 117  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  117
# 118  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  118
# 119  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  119
# 120  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  120
# 121  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  121
#
# [122 rows x 3 columns]

# %%
data.to_csv('pre_final_coregistration.csv', index=False)

# %%
from main import make_train_valid_dfs
import config as CFG
train_dataframe, valid_dataframe = make_train_valid_dfs()

# %%
train_dataframe
# Out:
#                                                image1  \
# 0   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 1   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 2   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 3   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 4   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# ..                                                ...
# 75  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 76  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 77  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 78  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 79  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
#
#                                                image2  id
# 0   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   1
# 1   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   2
# 2   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   3
# 3   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   5
# 4   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   6
# ..                                                ...  ..
# 75  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  95
# 76  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  96
# 77  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  97
# 78  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  98
# 79  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  99
#
# [80 rows x 3 columns]

# %%
valid_dataframe
# Out:
#                                                image1  \
# 0   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 1   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 2   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 3   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 4   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 5   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 6   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 7   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 8   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 9   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 10  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 11  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 12  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 13  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 14  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 15  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 16  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 17  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 18  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
# 19  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...
#
#                                                image2  id
# 0   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   0
# 1   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...   4
# 2   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  10
# 3   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  12
# 4   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  18
# 5   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  22
# 6   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  30
# 7   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  31
# 8   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  33
# 9   /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  39
# 10  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  44
# 11  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  45
# 12  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  53
# 13  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  70
# 14  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  73
# 15  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  76
# 16  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  77
# 17  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  80
# 18  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  83
# 19  /home/gridsan/nchutisilp/datasets/Mariia/Pre_F...  90

# %%
pre_final_coregistration = Path('/home/gridsan/nchutisilp/datasets/Mariia/Pre_Post')

image_filenames1 = pre_final_coregistration.glob('*Pre_target_Post.nii.gz')
image_filenames2 = pre_final_coregistration.glob('*Post_reg.nii.gz')

image_filenames1 = list(image_filenames1)
image_filenames2 = list(image_filenames2)

image_filenames1.sort()
image_filenames2.sort()

for image_path1, image_path2 in zip(image_filenames1, image_filenames2):
    last_numeric_index = 6
    if not image_path1.name[:last_numeric_index].isnumeric():
        last_numeric_index = 5
    assert image_path1.name[:last_numeric_index] == image_path2.name[:last_numeric_index], f'Image paths do not align, {image_path1} and {image_path2} should have the same case id'

data = pd.DataFrame({
    'image1': image_filenames1,
    'image2': image_filenames2
})
data['id'] = data.index

data.to_csv('pre_post_coregistration.csv', index=False)
